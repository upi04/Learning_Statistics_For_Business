# %% [markdown]
# ## Case 2 - Fast Food Marketing Campaign
#
# **Scenario**<br>
# A fast-food chain plans to add a new item to its menu. However, they are still undecided between three possible marketing campaigns for promoting the new product. In order to determine which promotion has the greatest effect on sales, the new item is introduced at locations in several randomly selected markets. A different promotion is used at each location, and the weekly sales of the new item are recorded for the first four weeks.
#
# **Goal**<br>
# Describe the characteristics of the Data
#
# **Description of Variables**<br>
# 1. MarketID: unique identifier for market
# 2. MarketSize: size of market area by sales
# 3. LocationID: unique identifier for store location
# 4. AgeOfStore: age of store in years
# 5. Promotion: one of three promotions that were tested
# 6. week: one of four weeks when the promotions were run
# 7. SalesInThousands: sales amount for a specific LocationID, Promotion, and week
#
# ### Import Dataset

# %%
import pandas as pd

# Now you can read the dataset
df2 = pd.read_csv('Marketing-Campaign.csv')
df2.head()
# Out:
#    MarketID MarketSize  LocationID  AgeOfStore  Promotion  week  \
# 0         1     Medium           1           4          3     1
# 1         1     Medium           1           4          3     2
# 2         1     Medium           1           4          3     3
# 3         1     Medium           1           4          3     4
# 4         1     Medium           2           5          2     1
#
#    SalesInThousands
# 0             33.73
# 1             35.67
# 2             29.03
# 3             39.25
# 4             27.81

# %% [markdown]
# Get how many promotion that used in this data

# %%
df2['Promotion'].unique()
# Out:
# array([3, 2, 1])

# %%
#change the word in Promotion Variables
df2["Promotion"].replace({1:"promotion_1",2:"promotion_2",3:"promotion_3"}, inplace=True)
df2['Promotion'].unique()
# Out:
# <ipython-input-5-70a2c0ea48bd>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["Promotion"].replace({1:"promotion_1",2:"promotion_2",3:"promotion_3"}, inplace=True)
# array(['promotion_3', 'promotion_2', 'promotion_1'], dtype=object)

# %% [markdown]
# How many weeks the campaign occur?

# %%
#change the value in week Variables
df2["week"].replace({1:"week_1",2:"week_2",3:"week_3",4:"week_4"}, inplace=True)
df2['week'].unique()
# Out:
# <ipython-input-6-69065c2d365d>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["week"].replace({1:"week_1",2:"week_2",3:"week_3",4:"week_4"}, inplace=True)
# array(['week_1', 'week_2', 'week_3', 'week_4'], dtype=object)

# %%
#change the value in MarketID Variables
df2["MarketID"].replace({1:"001",2:"002",3:"003",4:"004",5:"005",6:"006",7:"007",8:"008",9:"009",10:"010"}, inplace=True)

#change 'LocationID' to string
df2['LocationID'] = df2['LocationID'].astype('str')
# Out:
# <ipython-input-7-f61a8f840d5c>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["MarketID"].replace({1:"001",2:"002",3:"003",4:"004",5:"005",6:"006",7:"007",8:"008",9:"009",10:"010"}, inplace=True)

# %%
#checking missing value
df2.isnull().any()
# Out:
# MarketID            False
# MarketSize          False
# LocationID          False
# AgeOfStore          False
# Promotion           False
# week                False
# SalesInThousands    False
# dtype: bool

# %% [markdown]
# There is no missing value in this data

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MarketID          548 non-null    object
#  1   MarketSize        548 non-null    object
#  2   LocationID        548 non-null    object
#  3   AgeOfStore        548 non-null    int64
#  4   Promotion         548 non-null    object
#  5   week              548 non-null    object
#  6   SalesInThousands  548 non-null    float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 30.1+ KB

# %% [markdown]
# Dataset has 7 columns and 548 rows
# ### Numerical Variables
# We will explore the numerical variables (`AgeOfStore`,`SalesInThousands`) in the data.
#
#
# Show the descriptive statistics of numerical variables

# %%
df2.describe()
# Out:
#        AgeOfStore  SalesInThousands
# count  548.000000        548.000000
# mean     8.503650         53.466204
# std      6.638345         16.755216
# min      1.000000         17.340000
# 25%      4.000000         42.545000
# 50%      7.000000         50.200000
# 75%     12.000000         60.477500
# max     28.000000         99.650000

# %% [markdown]
# The average sales of new item that introduced by different promotion at 10 location in 4 weeks is $53,466.2

# %%
df2.loc[df2['SalesInThousands']==min(df2['SalesInThousands'])]
# Out:
#     MarketID MarketSize LocationID  AgeOfStore    Promotion    week  \
# 285      006     Medium        507           5  promotion_2  week_2
#
#      SalesInThousands
# 285             17.34

# %% [markdown]
# The data that has a minimum sales came from MarketID 006 that use promotion_2

# %%
df2.loc[df2['SalesInThousands']==max(df2['SalesInThousands'])]
# Out:
#     MarketID MarketSize LocationID  AgeOfStore    Promotion    week  \
# 144      003      Large        218           2  promotion_1  week_1
#
#      SalesInThousands
# 144             99.65

# %% [markdown]
# The data that has a maximum sales came from MarketID 003 that use promotion_1
#
# #### Exercise
#
# 1. Compare the descriptive statistics of the data that has the maximum and minumum age of the store

# %%
df2.loc[df2['AgeOfStore']==max(df2['AgeOfStore'])].describe()
df2.loc[df2['AgeOfStore']==min(df2['AgeOfStore'])].describe()
# Out:
#        AgeOfStore  SalesInThousands
# count        80.0         80.000000
# mean          1.0         58.415625
# std           0.0         17.410955
# min           1.0         24.770000
# 25%           1.0         47.445000
# 50%           1.0         55.170000
# 75%           1.0         63.962500
# max           1.0         97.610000

# %%
df2.loc[df2['AgeOfStore']==min(df2['AgeOfStore'])].describe()
# Out:
#        AgeOfStore  SalesInThousands
# count        80.0         80.000000
# mean          1.0         58.415625
# std           0.0         17.410955
# min           1.0         24.770000
# 25%           1.0         47.445000
# 50%           1.0         55.170000
# 75%           1.0         63.962500
# max           1.0         97.610000

# %% [markdown]
# 4. what is the characteristic of the data that has the maximum age of the store?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create pairplot
sns.pairplot(df2)

# Display the plot
plt.show()

# %%
# Get correlation between numeric variables
df2[["AgeOfStore","SalesInThousands"]].corr()
# Out:
#                   AgeOfStore  SalesInThousands
# AgeOfStore          1.000000         -0.028533
# SalesInThousands   -0.028533          1.000000

# %% [markdown]
# The correlation of Age of store and sales in -0.028. It's very weak and has opposite relationship. So, we can assume there is no linear relationship between sales and age of store.
#
# Let's plot the average sales of each store age

# %%
df_as = df2.groupby("AgeOfStore")["SalesInThousands"].mean()
df_as.plot()
plt.ylabel("AVG of Sales In Thousands")
plt.show()

# %% [markdown]
# Average of Sales in each age of store does not show any particular pattern. So, we can not try to get better sales just from age of store.
#
# ### Categorical Variables
#
# We will explore the categorical variables `Promotion`,`MarketID`,`MarketSize`, `Week`, and thei relationship in the data.
#
# 1. Promotion

# %%
# get the number of sales in each Promotion
df2.groupby(['Promotion']).size()
# Out:
# Promotion
# promotion_1    172
# promotion_2    188
# promotion_3    188
# dtype: int64

# %%
sns.countplot(x ='Promotion', data = df2)
plt.show()

# %% [markdown]
# There's no difference in sales form three promotion, but the promotions made for the first were a bit lower than for the second and third
# 2. MarketID

# %%
# get the number of sales in each MarketID
df2.groupby(['MarketID']).size()
# Out:
# MarketID
# 001    52
# 002    24
# 003    88
# 004    36
# 005    60
# 006    60
# 007    60
# 008    48
# 009    40
# 010    80
# dtype: int64

# %%
sns.countplot(x ='MarketID', data = df2)
plt.show()

# %%
df2['MarketID'].mode()
# Out:
# 0    003
# Name: MarketID, dtype: object

# %% [markdown]
# The most participant market for the campaign is `MarketID 003`. And the lowest is `MarketID 002`
# 3. Week

# %%
# get the number of sales in each week
df2.groupby(['week']).size()
# Out:
# week
# week_1    137
# week_2    137
# week_3    137
# week_4    137
# dtype: int64

# %%
sns.countplot(x ='week', data = df2)
plt.show()

# %% [markdown]
# In this campaign equalize the number of weekly sales
# 4. MarketSize

# %%
#get the number of sales in each MarketSize
df2.groupby(['MarketSize']).size()
# Out:
# MarketSize
# Large     168
# Medium    320
# Small      60
# dtype: int64

# %%
sns.countplot(x ='MarketSize', data = df2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Medium-sized markets have a higher number of sales than small and large markets.
#
# 5. MarketID vs Promotion

# %%
# Get the percentage of sales in each MarketID and promotion
df2.groupby(['MarketID', 'Promotion']).size().unstack()*(100/len(df2))
# Out:
# Promotion  promotion_1  promotion_2  promotion_3
# MarketID
# 001           3.649635     3.649635     2.189781
# 002           0.729927          NaN     3.649635
# 003           5.109489     4.379562     6.569343
# 004           2.919708     2.919708     0.729927
# 005           1.459854     5.839416     3.649635
# 006           3.649635     4.379562     2.919708
# 007           2.919708     2.919708     5.109489
# 008           3.649635     1.459854     3.649635
# 009           2.189781     1.459854     3.649635
# 010           5.109489     7.299270     2.189781

# %%
fig, ax = plt.subplots(figsize=(10,10))
df2.groupby(['Promotion', 'MarketID']).size().unstack().plot(kind='bar', ax=ax)
plt.show()

# %% [markdown]
# *   `MarketID 002` didn't buy new item in second promotion
# *   The most sales occurred at `MarketID 010` in the `Second Promotion`
#
# 6. Week vs Promotion

# %%
# get the percentage of sales in each week and promotion
df2.groupby(['week', 'Promotion']).size().unstack()
# Out:
# Promotion  promotion_1  promotion_2  promotion_3
# week
# week_1              43           47           47
# week_2              43           47           47
# week_3              43           47           47
# week_4              43           47           47

# %%
fig, ax = plt.subplots(figsize=(10,10))
df2.groupby(['Promotion', 'week']).size().unstack().plot(kind='bar', ax=ax)
plt.show()

# %% [markdown]
# The distribution of the number of promotions in each week is the same, namely 43 sales for the first promotion in the first week, and 47 sales for the second and third promotions in other weeks
# #### Exercise
#
# Show how the number of sales in each MarketSize and Promotion

# %%
df2.groupby(['MarketSize', 'Promotion']).size().unstack()
fig, ax = plt.subplots(figsize=(10,10))
df2.groupby(['Promotion', 'MarketSize']).size().unstack().plot(kind='bar', ax=ax)
plt.show()

# %% [markdown]
# ### Categorical and Numerical Variables
#
# 1. Promotion vs Sales in Thousands

# %%
df2.groupby(["Promotion"]).agg({"SalesInThousands":["count","mean","median","sum"]})
# Out:
#             SalesInThousands
#                        count       mean  median       sum
# Promotion
# promotion_1              172  58.099012  55.385   9993.03
# promotion_2              188  47.329415  45.385   8897.93
# promotion_3              188  55.364468  51.165  10408.52

# %% [markdown]
# - Even though promotion 1 didn't have a lot of sales, the average of income for promotion 1 was more than the others
# - The largest sum of sales in thousand comes from promotion 3

# %%
sns.boxplot(x = "SalesInThousands", y="Promotion", data=df2)
plt.show()

# %% [markdown]
# - The maximum sales in thousands comes from promotion 1
# - Promotion 1 and 3 do not have much different variability, but promotion 3 has a bit more variability.
# - All the promotions have potential outlier
# 2. MarketID vs Sales In Thousands

# %%
df2.groupby(["MarketID"]).agg({"SalesInThousands":["count","mean","median","sum"]})
# Out:
#          SalesInThousands
#                     count       mean  median      sum
# MarketID
# 001                    52  35.101731  35.675  1825.29
# 002                    24  61.761250  61.875  1482.27
# 003                    88  84.971705  84.090  7477.51
# 004                    36  54.508056  54.035  1962.29
# 005                    60  48.838000  48.740  2930.28
# 006                    60  36.397500  36.750  2183.85
# 007                    60  44.475333  43.385  2668.52
# 008                    48  48.952917  49.650  2349.74
# 009                    40  52.940750  52.525  2117.63
# 010                    80  53.776250  52.930  4302.10

# %% [markdown]
# * `MarketID 003` with the highest number of sales also get the most revenue
# * The lowest average income is from `MarketID 001`

# %%
sns.boxplot(x = "SalesInThousands", y="MarketID", data=df2)
plt.show()

# %% [markdown]
# * Even though `MarketID 002` did not buy new item on promotion 2 (see in MarketID vs Promotion section), It is the second largest in median sales in thousands.
# * The lowest median income is from `MarketID 001`, but the lowest income occurs at `MarketID 006`.
# * `MarketID 002` has lowest variability than others
# 3. Week vs Sales in Thousands

# %%
df2.groupby(["week"]).agg({"SalesInThousands":["count","mean","median","sum"]})
# Out:
#        SalesInThousands
#                   count       mean median      sum
# week
# week_1              137  53.790584  50.20  7369.31
# week_2              137  53.386569  51.09  7313.96
# week_3              137  53.474599  50.11  7326.02
# week_4              137  53.213066  49.71  7290.19

# %%
df_we = df2.groupby("week")["SalesInThousands"].mean()
df_we.plot()
plt.ylabel("AVG of Sales In Thousands")
plt.show()

# %%
sns.boxplot(x = "SalesInThousands", y="week", data=df2)
plt.show()

# %% [markdown]
# Every week there is no significant difference in sales. Only a difference of 500 dollars for the highest and lowest.
#
# 4. MarketSize vs Sales in Thousands

# %%
sns.boxplot(x = "SalesInThousands", y="MarketSize", data=df2)
plt.show()

# %%
df_we = df2.groupby("MarketSize")["SalesInThousands"].mean()
df_we.plot(kind='bar')
plt.ylabel("AVG of Sales In Thousands")
plt.show()

# %% [markdown]
# * Even though the medium size participates more in each of its promotions, the medium size gets the least sales value
#
# 5. Promotion vs Sales in Thousands vs MarketID

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="Promotion", y="SalesInThousands", hue="MarketID", data=df2)
plt.show()

# %% [markdown]
# It can be seen that promotion 1 has the highest revenue return compared to promotions 2 and 3 in the entire market
# 6. Promotion vs Sales in Thousands vs Week

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="Promotion", y="SalesInThousands", hue="week", data=df2)
plt.show()

# %% [markdown]
# * in every week, there is no huge difference in sales.
# * Promotion 1 earns higher revenue each week.
# 7. Promotion vs Sales in Thousands vs MarketSize

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="Promotion", y="SalesInThousands", hue="MarketSize", data=df2)
plt.show()

# %% [markdown]
# * In every promotion, a large market size always gets bigger sales compared to small and medium.
# * The large market size gets the most sales going on promotions 3.
# * Even though the medium size participates more in each of its promotions, the medium size gets the least sales value
